# %% [markdown]
# ### Data Collection
# Web scraping was done from https://fbref.com/en/comps/12/La-Liga-Stats to obtain the necessary data regarding La Liga. Beautiful Soup ibrary was used for the web scraping

# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
data =requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select("table.stats_table")[0]

# %%
links = standings_table.find_all("a")

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if "/squads/" in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time                 Comp                     Round  Day  \
# 0   2022-08-13  21:00              La Liga               Matchweek 1  Sat
# 1   2022-08-21  22:00              La Liga               Matchweek 2  Sun
# 2   2022-08-28  19:30              La Liga               Matchweek 3  Sun
# 3   2022-09-03  21:00              La Liga               Matchweek 4  Sat
# 4   2022-09-07  21:00         Champions Lg               Group stage  Wed
# 5   2022-09-10  18:30              La Liga               Matchweek 5  Sat
# 6   2022-09-13  21:00         Champions Lg               Group stage  Tue
# 7   2022-09-17  16:15              La Liga               Matchweek 6  Sat
# 8   2022-10-01  21:00              La Liga               Matchweek 7  Sat
# 9   2022-10-04  21:00         Champions Lg               Group stage  Tue
# 10  2022-10-09  21:00              La Liga               Matchweek 8  Sun
# 11  2022-10-12  21:00         Champions Lg               Group stage  Wed
# 12  2022-10-16  16:15              La Liga               Matchweek 9  Sun
# 13  2022-10-20  21:00              La Liga              Matchweek 10  Thu
# 14  2022-10-23  21:00              La Liga              Matchweek 11  Sun
# 15  2022-10-26  21:00         Champions Lg               Group stage  Wed
# 16  2022-10-29  21:00              La Liga              Matchweek 12  Sat
# 17  2022-11-01  21:00         Champions Lg               Group stage  Tue
# 18  2022-11-05  21:00              La Liga              Matchweek 13  Sat
# 19  2022-11-08  21:30              La Liga              Matchweek 14  Tue
# 20  2022-12-31  14:00              La Liga              Matchweek 15  Sat
# 21  2023-01-08  21:00              La Liga              Matchweek 16  Sun
# 22  2023-01-12  22:00  Supercopa de España               Semi-finals  Thu
# 23  2023-01-22    NaN              La Liga              Matchweek 18  Sun
# 24  2023-01-29    NaN              La Liga              Matchweek 19  Sun
# 25  2023-02-01  21:00              La Liga              Matchweek 17  Wed
# 26  2023-02-05    NaN              La Liga              Matchweek 20  Sun
# 27  2023-02-12    NaN              La Liga              Matchweek 21  Sun
# 28  2023-02-16  18:45            Europa Lg  Knockout round play-offs  Thu
# 29  2023-02-19    NaN              La Liga              Matchweek 22  Sun
# 30  2023-02-23  20:00            Europa Lg  Knockout round play-offs  Thu
# 31  2023-02-26    NaN              La Liga              Matchweek 23  Sun
# 32  2023-03-05    NaN              La Liga              Matchweek 24  Sun
# 33  2023-03-12    NaN              La Liga              Matchweek 25  Sun
# 34  2023-03-19    NaN              La Liga              Matchweek 26  Sun
# 35  2023-04-02    NaN              La Liga              Matchweek 27  Sun
# 36  2023-04-09    NaN              La Liga              Matchweek 28  Sun
# 37  2023-04-16    NaN              La Liga              Matchweek 29  Sun
# 38  2023-04-23    NaN              La Liga              Matchweek 30  Sun
# 39  2023-04-26    NaN              La Liga              Matchweek 31  Wed
# 40  2023-04-30    NaN              La Liga              Matchweek 32  Sun
# 41  2023-05-03    NaN              La Liga              Matchweek 33  Wed
# 42  2023-05-14    NaN              La Liga              Matchweek 34  Sun
# 43  2023-05-21    NaN              La Liga              Matchweek 35  Sun
# 44  2023-05-24    NaN              La Liga              Matchweek 36  Wed
# 45  2023-05-28    NaN              La Liga              Matchweek 37  Sun
# 46  2023-06-04    NaN              La Liga              Matchweek 38  Sun
#
#    Venue Result   GF   GA            Opponent   xG  xGA  Poss  Attendance  \
# 0   Home      D  0.0  0.0      Rayo Vallecano  1.9  0.5  67.0     81104.0
# 1   Away      W  4.0  1.0       Real Sociedad  2.1  0.8  58.0     36201.0
# 2   Home      W  4.0  0.0          Valladolid  2.6  0.8  67.0     83972.0
# 3   Away      W  3.0  0.0             Sevilla  4.0  1.0  54.0     40233.0
# 4   Home      W  5.0  1.0   cz Viktoria Plzeň  2.3  0.8  76.0     77411.0
# 5   Away      W  4.0  0.0               Cádiz  3.4  0.4  70.0     19530.0
# 6   Away      L  0.0  2.0    de Bayern Munich  2.0  1.7  53.0     75000.0
# 7   Home      W  3.0  0.0               Elche  3.9  0.0  76.0     85073.0
# 8   Away      W  1.0  0.0            Mallorca  0.7  1.2  71.0     18103.0
# 9   Away      L  0.0  1.0            it Inter  0.5  0.2  71.0     71368.0
# 10  Home      W  1.0  0.0          Celta Vigo  2.0  1.5  57.0     81525.0
# 11  Home      D  3.0  3.0            it Inter  2.2  2.0  61.0     92302.0
# 12  Away      L  1.0  3.0         Real Madrid  2.0  1.1  56.0     62876.0
# 13  Home      W  3.0  0.0          Villarreal  2.1  0.4  69.0     73261.0
# 14  Home      W  4.0  0.0       Athletic Club  1.4  0.5  65.0     84817.0
# 15  Home      L  0.0  3.0    de Bayern Munich  0.7  2.1  52.0     84016.0
# 16  Away      W  1.0  0.0            Valencia  1.6  0.2  67.0     46007.0
# 17  Away      W  4.0  2.0   cz Viktoria Plzeň  2.3  2.6  76.0     11258.0
# 18  Home      W  2.0  0.0             Almería  4.0  0.5  70.0     92605.0
# 19  Away      W  2.0  1.0             Osasuna  0.8  1.0  53.0     21603.0
# 20  Home    NaN  NaN  NaN            Espanyol  NaN  NaN   NaN         NaN
# 21  Away    NaN  NaN  NaN     Atlético Madrid  NaN  NaN   NaN         NaN
# 22  Away    NaN  NaN  NaN               Betis  NaN  NaN   NaN         NaN
# 23  Home    NaN  NaN  NaN              Getafe  NaN  NaN   NaN         NaN
# 24  Away    NaN  NaN  NaN              Girona  NaN  NaN   NaN         NaN
# 25  Away    NaN  NaN  NaN               Betis  NaN  NaN   NaN         NaN
# 26  Home    NaN  NaN  NaN             Sevilla  NaN  NaN   NaN         NaN
# 27  Away    NaN  NaN  NaN          Villarreal  NaN  NaN   NaN         NaN
# 28  Home    NaN  NaN  NaN  eng Manchester Utd  NaN  NaN   NaN         NaN
# 29  Home    NaN  NaN  NaN               Cádiz  NaN  NaN   NaN         NaN
# 30  Away    NaN  NaN  NaN  eng Manchester Utd  NaN  NaN   NaN         NaN
# 31  Away    NaN  NaN  NaN             Almería  NaN  NaN   NaN         NaN
# 32  Home    NaN  NaN  NaN            Valencia  NaN  NaN   NaN         NaN
# 33  Away    NaN  NaN  NaN       Athletic Club  NaN  NaN   NaN         NaN
# 34  Home    NaN  NaN  NaN         Real Madrid  NaN  NaN   NaN         NaN
# 35  Away    NaN  NaN  NaN               Elche  NaN  NaN   NaN         NaN
# 36  Home    NaN  NaN  NaN              Girona  NaN  NaN   NaN         NaN
# 37  Away    NaN  NaN  NaN              Getafe  NaN  NaN   NaN         NaN
# 38  Home    NaN  NaN  NaN     Atlético Madrid  NaN  NaN   NaN         NaN
# 39  Away    NaN  NaN  NaN      Rayo Vallecano  NaN  NaN   NaN         NaN
# 40  Home    NaN  NaN  NaN               Betis  NaN  NaN   NaN         NaN
# 41  Home    NaN  NaN  NaN             Osasuna  NaN  NaN   NaN         NaN
# 42  Away    NaN  NaN  NaN            Espanyol  NaN  NaN   NaN         NaN
# 43  Home    NaN  NaN  NaN       Real Sociedad  NaN  NaN   NaN         NaN
# 44  Away    NaN  NaN  NaN          Valladolid  NaN  NaN   NaN         NaN
# 45  Home    NaN  NaN  NaN            Mallorca  NaN  NaN   NaN         NaN
# 46  Away    NaN  NaN  NaN          Celta Vigo  NaN  NaN   NaN         NaN
#
#                   Captain Formation              Referee  Match Report  \
# 0         Sergio Busquets     4-3-3  Alejandro Hernández  Match Report
# 1   Marc-André ter Stegen   3-2-4-1    José Luis Munuera  Match Report
# 2         Sergio Busquets     4-3-3    Ricardo de Burgos  Match Report
# 3         Sergio Busquets     4-3-3  Antonio Matéu Lahoz  Match Report
# 4           Sergi Roberto     4-3-3      Lawrence Visser  Match Report
# 5         Sergio Busquets     4-3-3     Carlos del Cerro  Match Report
# 6         Sergio Busquets     4-3-3       Danny Makkelie  Match Report
# 7   Marc-André ter Stegen     4-3-3      Alejandro Muñíz  Match Report
# 8         Sergio Busquets     4-3-3            Jesús Gil  Match Report
# 9         Sergio Busquets     4-3-3        Slavko Vinčič  Match Report
# 10        Sergio Busquets     4-3-3    José Luis Munuera  Match Report
# 11        Sergio Busquets     4-3-3     Szymon Marciniak  Match Report
# 12        Sergio Busquets     4-3-3         José Sánchez  Match Report
# 13          Sergi Roberto     4-3-3     Carlos del Cerro  Match Report
# 14        Sergio Busquets     4-3-3        Juan Martínez  Match Report
# 15        Sergio Busquets     4-3-3       Anthony Taylor  Match Report
# 16        Sergio Busquets     4-3-3    Ricardo de Burgos  Match Report
# 17           Gerard Piqué     4-3-3        Radu Petrescu  Match Report
# 18           Gerard Piqué     4-3-3       Pablo González  Match Report
# 19        Sergio Busquets     4-3-3            Jesús Gil  Match Report
# 20                    NaN       NaN                  NaN  Head-to-Head
# 21                    NaN       NaN                  NaN  Head-to-Head
# 22                    NaN       NaN                  NaN  Head-to-Head
# 23                    NaN       NaN                  NaN  Head-to-Head
# 24                    NaN       NaN                  NaN  Head-to-Head
# 25                    NaN       NaN                  NaN  Head-to-Head
# 26                    NaN       NaN                  NaN  Head-to-Head
# 27                    NaN       NaN                  NaN  Head-to-Head
# 28                    NaN       NaN                  NaN  Head-to-Head
# 29                    NaN       NaN                  NaN  Head-to-Head
# 30                    NaN       NaN                  NaN  Head-to-Head
# 31                    NaN       NaN                  NaN  Head-to-Head
# 32                    NaN       NaN                  NaN  Head-to-Head
# 33                    NaN       NaN                  NaN  Head-to-Head
# 34                    NaN       NaN                  NaN  Head-to-Head
# 35                    NaN       NaN                  NaN  Head-to-Head
# 36                    NaN       NaN                  NaN  Head-to-Head
# 37                    NaN       NaN                  NaN  Head-to-Head
# 38                    NaN       NaN                  NaN  Head-to-Head
# 39                    NaN       NaN                  NaN  Head-to-Head
# 40                    NaN       NaN                  NaN  Head-to-Head
# 41                    NaN       NaN                  NaN  Head-to-Head
# 42                    NaN       NaN                  NaN  Head-to-Head
# 43                    NaN       NaN                  NaN  Head-to-Head
# 44                    NaN       NaN                  NaN  Head-to-Head
# 45                    NaN       NaN                  NaN  Head-to-Head
# 46                    NaN       NaN                  NaN  Head-to-Head
#
#          Notes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28  Leg 1 of 2
# 29         NaN
# 30  Leg 2 of 2
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all("a")

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and "all_comps/shooting/" in l]

# %%
links
# Out:
# ['/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions',
#  '/en/squads/206d90db/2022-2023/matchlogs/all_comps/shooting/Barcelona-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match= "Shooting")[0]

# %%
shooting.head()
# Out:
#   For Barcelona                                                            \
#            Date   Time          Comp        Round  Day Venue Result GF GA
# 0    2022-08-13  21:00       La Liga  Matchweek 1  Sat  Home      D  0  0
# 1    2022-08-21  22:00       La Liga  Matchweek 2  Sun  Away      W  4  1
# 2    2022-08-28  19:30       La Liga  Matchweek 3  Sun  Home      W  4  0
# 3    2022-09-03  21:00       La Liga  Matchweek 4  Sat  Away      W  3  0
# 4    2022-09-07  21:00  Champions Lg  Group stage  Wed  Home      W  5  1
#
#                       ... Standard             Expected                    \
#             Opponent  ...     Dist FK PK PKatt       xG npxG npxG/Sh G-xG
# 0     Rayo Vallecano  ...     17.0  1  0     0      1.9  1.9    0.09 -1.9
# 1      Real Sociedad  ...     14.6  0  0     0      2.1  2.1    0.14  1.9
# 2         Valladolid  ...     14.4  1  0     0      2.6  2.6    0.12  1.4
# 3            Sevilla  ...     16.0  2  0     0      4.0  4.0    0.24 -1.0
# 4  cz Viktoria Plzeň  ...     16.2  0  0     0      2.3  2.3    0.11  2.7
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0    -1.9        Match Report
# 1     1.9        Match Report
# 2     1.4        Match Report
# 3    -1.0        Match Report
# 4     2.7        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result  GF  GA  \
# 0  2022-08-13  21:00       La Liga  Matchweek 1  Sat  Home      D   0   0
# 1  2022-08-21  22:00       La Liga  Matchweek 2  Sun  Away      W   4   1
# 2  2022-08-28  19:30       La Liga  Matchweek 3  Sun  Home      W   4   0
# 3  2022-09-03  21:00       La Liga  Matchweek 4  Sat  Away      W   3   0
# 4  2022-09-07  21:00  Champions Lg  Group stage  Wed  Home      W   5   1
#
#             Opponent  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0     Rayo Vallecano  ...  17.0   1   0      0  1.9   1.9     0.09  -1.9
# 1      Real Sociedad  ...  14.6   0   0      0  2.1   2.1     0.14   1.9
# 2         Valladolid  ...  14.4   1   0      0  2.6   2.6     0.12   1.4
# 3            Sevilla  ...  16.0   2   0      0  4.0   4.0     0.24  -1.0
# 4  cz Viktoria Plzeň  ...  16.2   0   0      0  2.3   2.3     0.11   2.7
#
#    np:G-xG  Match Report
# 0     -1.9  Match Report
# 1      1.9  Match Report
# 2      1.4  Match Report
# 3     -1.0  Match Report
# 4      2.7  Match Report
#
# [5 rows x 26 columns]

# %%
shooting.shape
# Out:
# (21, 26)

# %%
matches[0].shape
# Out:
# (47, 19)

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on = "Date")

# %%
team_data.head(5)
# Out:
#          Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-13  21:00       La Liga  Matchweek 1  Sat  Home      D  0.0  0.0
# 1  2022-08-21  22:00       La Liga  Matchweek 2  Sun  Away      W  4.0  1.0
# 2  2022-08-28  19:30       La Liga  Matchweek 3  Sun  Home      W  4.0  0.0
# 3  2022-09-03  21:00       La Liga  Matchweek 4  Sat  Away      W  3.0  0.0
# 4  2022-09-07  21:00  Champions Lg  Group stage  Wed  Home      W  5.0  1.0
#
#             Opponent  ...                Captain  Formation  \
# 0     Rayo Vallecano  ...        Sergio Busquets      4-3-3
# 1      Real Sociedad  ...  Marc-André ter Stegen    3-2-4-1
# 2         Valladolid  ...        Sergio Busquets      4-3-3
# 3            Sevilla  ...        Sergio Busquets      4-3-3
# 4  cz Viktoria Plzeň  ...          Sergi Roberto      4-3-3
#
#                Referee  Match Report Notes  Sh SoT  Dist PK  PKatt
# 0  Alejandro Hernández  Match Report   NaN  21   5  17.0  0      0
# 1    José Luis Munuera  Match Report   NaN  15   7  14.6  0      0
# 2    Ricardo de Burgos  Match Report   NaN  24   9  14.4  0      0
# 3  Antonio Matéu Lahoz  Match Report   NaN  18   5  16.0  0      0
# 4      Lawrence Visser  Match Report   NaN  20  10  16.2  0      0
#
# [5 rows x 24 columns]

# %%
years = list(range(2022, 2011, -1))
all_matches = []

# %%
years
# Out:
# [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012]

# %%
standings_url = "https://fbref.com/en/comps/12/La-Liga-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select("table.stats_table")[0]
    
    links = [l.get("href") for l in standings_table.find_all("a")]
    links = [l for l in links if "/squads/" in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all("a")]
        links = [l for l in links if l and "all_comps/shooting/" in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match = "Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on = "Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "La Liga"]
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
match_df = pd.concat(all_matches)

# %%
match_df
# Out:
#           Date   Time     Comp         Round  Day Venue Result GF GA  \
# 0   2022-08-13  21:00  La Liga   Matchweek 1  Sat  Home      D  0  0
# 1   2022-08-21  22:00  La Liga   Matchweek 2  Sun  Away      W  4  1
# 2   2022-08-28  19:30  La Liga   Matchweek 3  Sun  Home      W  4  0
# 3   2022-09-03  21:00  La Liga   Matchweek 4  Sat  Away      W  3  0
# 5   2022-09-10  18:30  La Liga   Matchweek 5  Sat  Away      W  4  0
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 33  2013-05-05    NaN  La Liga  Matchweek 34  Sun  Home      W  3  0
# 34  2013-05-10    NaN  La Liga  Matchweek 35  Fri  Away      D  0  0
# 35  2013-05-19    NaN  La Liga  Matchweek 36  Sun  Home      L  1  2
# 36  2013-05-26    NaN  La Liga  Matchweek 37  Sun  Away      L  0  4
# 37  2013-06-01    NaN  La Liga  Matchweek 38  Sat  Home      L  1  3
#
#            Opponent  ...              Referee  Match Report  Notes    Sh  SoT  \
# 0    Rayo Vallecano  ...  Alejandro Hernández  Match Report    NaN  21.0  5.0
# 1     Real Sociedad  ...    José Luis Munuera  Match Report    NaN  15.0  7.0
# 2        Valladolid  ...    Ricardo de Burgos  Match Report    NaN  24.0  9.0
# 3           Sevilla  ...  Antonio Matéu Lahoz  Match Report    NaN  18.0  5.0
# 5             Cádiz  ...     Carlos del Cerro  Match Report    NaN  16.0  8.0
# ..              ...  ...                  ...           ...    ...   ...  ...
# 33   Rayo Vallecano  ...    Teixeira Vitienes  Match Report    NaN   NaN  NaN
# 34          Levante  ...          Gil Manzano  Match Report    NaN   NaN  NaN
# 35    Athletic Club  ...     Del Cerro Grande  Match Report    NaN   NaN  NaN
# 36            Betis  ...          Mateu Lahoz  Match Report    NaN   NaN  NaN
# 37  Atlético Madrid  ...    Estrada Fernández  Match Report    NaN   NaN  NaN
#
#     Dist   PK PKatt Season       Team
# 0   17.0  0.0   0.0   2022  Barcelona
# 1   14.6  0.0   0.0   2022  Barcelona
# 2   14.4  0.0   0.0   2022  Barcelona
# 3   16.0  0.0   0.0   2022  Barcelona
# 5   14.9  0.0   0.0   2022  Barcelona
# ..   ...  ...   ...    ...        ...
# 33   NaN  1.0   NaN   2012   Zaragoza
# 34   NaN  0.0   NaN   2012   Zaragoza
# 35   NaN  0.0   NaN   2012   Zaragoza
# 36   NaN  0.0   NaN   2012   Zaragoza
# 37   NaN  0.0   NaN   2012   Zaragoza
#
# [7880 rows x 26 columns]

# %%
match_df.to_csv("LaLiga matches.csv")
